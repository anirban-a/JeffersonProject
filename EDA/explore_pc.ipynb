# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
pd.set_option("max_rows", 25)

# %%
# Apply the default theme
sns.set_theme()
sns.set_style("whitegrid")

# %%
data_path = '/home/achara/data/achara/'

# %%
df = pd.read_csv(data_path + 'pc_data_2017_to_2019_2.csv')

# %%
df.head()
# Out:
#     DateTime  SensorDepth_Water_EXO  PC_Water_EXO  Chla_Water_EXO  \
# 0  10/1/2017                   1.01        0.1556        0.358058
# 1  10/1/2017                   1.03        0.1520        0.544445
# 2  10/1/2017                   1.05        0.1304        0.843708
# 3  10/1/2017                   1.07        0.1592        0.939807
# 4  10/1/2017                   1.09        0.1340        0.797623
#
#    DO_Water_EXO  DO-Sat_Water_EXO  SpCond_Water_EXO  Temperature_Water_EXO  \
# 0          9.17        101.610000        139.810000              20.380000
# 1          9.18        101.776667        139.786667              20.386667
# 2          9.16        101.230000        139.660000              20.220000
# 3          9.16        101.590000        139.780000              20.410000
# 4          9.15        101.490000        139.750000              20.420000
#
#    pH_Water_EXO  rel_fl  ...         TP       TSP       SRP        TN    NO3  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(
    data=df.groupby(['month'], as_index=False)['PC_Water_EXO'].mean(),
    x='month',
    y='PC_Water_EXO'
)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(
    data=df.groupby(['month'], as_index=False)['PRECTOTCORR'].mean(),
    x='month',
    y='PRECTOTCORR'
)
plt.show()

# %%
df.columns
# Out:
# Index(['DateTime', 'SensorDepth_Water_EXO', 'PC_Water_EXO', 'Chla_Water_EXO',
#        'DO_Water_EXO', 'DO-Sat_Water_EXO', 'SpCond_Water_EXO',
#        'Temperature_Water_EXO', 'pH_Water_EXO', 'rel_fl', 'month', 'day',
#        'year', 'SolarRad_Air_LiCor', 'TP', 'TSP', 'SRP', 'TN', 'NO3', 'NH4',
#        'PP', 'PRECTOTCORR', 'ALLSKY_SFC_SW_DWN', 'ALLSKY_SFC_LW_DWN'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.barplot(
    data=df.groupby(['month'], as_index=False)['Temperature_Water_EXO'].mean(),
    x='month',
    y='Temperature_Water_EXO'
)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.regplot(
    data=df.groupby(['month'], as_index=False)['PC_Water_EXO'].mean(),
    x='month',
    y='PC_Water_EXO',
    order=1
)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(
    data=df.groupby(['month'], as_index=False)['NH4'].mean(),
    x='month',
    y='NH4'
)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.regplot(data=df.groupby(['SensorDepth_Water_EXO'], as_index=False)['PC_Water_EXO'].mean(),
    x='SensorDepth_Water_EXO',
    y='PC_Water_EXO', order=1, line_kws={'color':'red'},)
plt.show()
